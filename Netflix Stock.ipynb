# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
nf1 = pd.read_csv('NFLX.csv')

# %%
dj = pd.read_csv('DJI.csv')

# %%
nfq = pd.read_csv('NFLX_daily_by_quarter.csv')

# %%
print(nf1.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-01  124.959999  143.460007  124.309998  140.710007  140.710007
# 1  2017-02-01  141.199997  145.949997  139.050003  142.130005  142.130005
# 2  2017-03-01  142.839996  148.289993  138.259995  147.809998  147.809998
# 3  2017-04-01  146.699997  153.520004  138.660004  152.199997  152.199997
# 4  2017-05-01  151.910004  164.750000  151.610001  163.070007  163.070007
#
#       Volume
# 0  181772200
# 1   91432000
# 2  110692700
# 3  149769200
# 4  116795800

# %%
nf1.rename(columns={'Adj Close':'Price'}, inplace=True)

# %%
print(nf1.head())
# Out:
#          Date        Open        High         Low       Close       Price  \
# 0  2017-01-01  124.959999  143.460007  124.309998  140.710007  140.710007
# 1  2017-02-01  141.199997  145.949997  139.050003  142.130005  142.130005
# 2  2017-03-01  142.839996  148.289993  138.259995  147.809998  147.809998
# 3  2017-04-01  146.699997  153.520004  138.660004  152.199997  152.199997
# 4  2017-05-01  151.910004  164.750000  151.610001  163.070007  163.070007
#
#       Volume
# 0  181772200
# 1   91432000
# 2  110692700
# 3  149769200
# 4  116795800

# %%
print(dj.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
# 2  2017-03-01  20957.289063  21169.109375  20412.800781  20663.220703
# 3  2017-04-01  20665.169922  21070.900391  20379.550781  20940.509766
# 4  2017-05-01  20962.730469  21112.320313  20553.449219  21008.650391
#
#       Adj Close      Volume
# 0  19864.089844  6482450000
# 1  20812.240234  6185580000
# 2  20663.220703  6941970000
# 3  20940.509766  5392630000
# 4  21008.650391  6613570000

# %%
dj.rename(columns={'Adj Close':'Price'}, inplace=True)

# %%
print(dj.head())
# Out:
#          Date          Open          High           Low         Close  \
# 0  2017-01-01  19872.859375  20125.580078  19677.939453  19864.089844
# 1  2017-02-01  19923.810547  20851.330078  19831.089844  20812.240234
# 2  2017-03-01  20957.289063  21169.109375  20412.800781  20663.220703
# 3  2017-04-01  20665.169922  21070.900391  20379.550781  20940.509766
# 4  2017-05-01  20962.730469  21112.320313  20553.449219  21008.650391
#
#           Price      Volume
# 0  19864.089844  6482450000
# 1  20812.240234  6185580000
# 2  20663.220703  6941970000
# 3  20940.509766  5392630000
# 4  21008.650391  6613570000

# %%
print(nfq.head())
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-01-03  124.959999  128.190002  124.309998  127.489998  127.489998
# 1  2017-01-04  127.489998  130.169998  126.550003  129.410004  129.410004
# 2  2017-01-05  129.220001  132.750000  128.899994  131.809998  131.809998
# 3  2017-01-06  132.080002  133.880005  129.809998  131.070007  131.070007
# 4  2017-01-09  131.479996  131.990005  129.889999  130.949997  130.949997
#
#      Volume Quarter
# 0   9437900      Q1
# 1   7843600      Q1
# 2  10185500      Q1
# 3  10657900      Q1
# 4   5766900      Q1

# %%
nfq.rename(columns={'Adj Close':'Price'}, inplace=True)

# %%
print(nfq.head())
# Out:
#          Date        Open        High         Low       Close       Price  \
# 0  2017-01-03  124.959999  128.190002  124.309998  127.489998  127.489998
# 1  2017-01-04  127.489998  130.169998  126.550003  129.410004  129.410004
# 2  2017-01-05  129.220001  132.750000  128.899994  131.809998  131.809998
# 3  2017-01-06  132.080002  133.880005  129.809998  131.070007  131.070007
# 4  2017-01-09  131.479996  131.990005  129.889999  130.949997  130.949997
#
#      Volume Quarter
# 0   9437900      Q1
# 1   7843600      Q1
# 2  10185500      Q1
# 3  10657900      Q1
# 4   5766900      Q1

# %%
f, ax = plt.subplots(figsize=(15, 10))
ax.set_title("Netflix Stock Price, Distribution")
sns.set_palette('Pastel1')
sns.violinplot(data=nfq, x='Quarter', y='Price')
sns.set_style('darkgrid')
plt.show()

# %%
x_positions = [1, 2, 3, 4]
chart_labels = ["1Q2017","2Q2017","3Q2017","4Q2017"]
earnings_actual =[.4, .15,.29,.41]
earnings_estimate = [.37,.15,.32,.41 ]
f, ax = plt.subplots(figsize=(8, 5))
ax.set_title("Earnings Per Share in Cents")
plt.scatter(x_positions,earnings_actual, color='red', alpha=0.5)
plt.scatter(x_positions, earnings_estimate, color='blue', alpha=0.5)
ax.legend(['Actual', 'Estimate'], loc=9)
plt.xticks(x_positions, chart_labels)
plt.show()

# %%
# The metrics below are in billions of dollars
revenue_by_quarter = [2.79, 2.98,3.29,3.7]
earnings_by_quarter = [.0656,.12959,.18552,.29012]
quarter_labels = ["2Q2017","3Q2017","4Q2017", "1Q2018"]

# Revenue
n = 1  
t = 2 
d = 4 
w = 0.8 
bars1_x = [t*element + w*n for element
             in range(d)]
plt.bar(bars1_x, revenue_by_quarter)

# Earnings
n = 2  
t = 2 
d = 4 
w = 0.8 
bars2_x = [t*element + w*n for element
             in range(d)]
plt.bar(bars2_x, earnings_by_quarter)

middle_x = [ (a + b) / 2.0 for a, b in zip(bars1_x, bars2_x)]
labels = ["Revenue", "Earnings"]
plt.title("Netflix Revenue versus Earnings")
plt.show()

# %%
ax1 = plt.subplot(1, 2, 1)
ax1.set_xlabel('Date')
ax1.set_ylabel('Stock Price')
ax1.set_title("Netflix")

plt.xticks(rotation='vertical')

plt.plot(nf1['Date'], nf1['Price'], color="red")

ax2 = plt.subplot(1, 2, 2)
ax2.set_xlabel('Date')
ax2.set_ylabel('Stock Price')
ax2.set_title("Dow Jones")
plt.xticks(rotation='vertical')
plt.plot(dj['Date'], dj['Price'], color="blue")
plt.subplots_adjust(wspace=.5)
plt.show()
